# %%
import numpy as np
data = np.loadtxt(fname='../week-four/inflammation-01.csv', delimiter=',')

# %%
print (data)
# Out:
# [[0. 0. 1. ... 3. 0. 0.]
#  [0. 1. 2. ... 1. 0. 1.]
#  [0. 1. 1. ... 2. 1. 1.]
#  ...
#  [0. 0. 1. ... 3. 0. 0.]
#  [0. 1. 2. ... 1. 0. 1.]
#  [0. 1. 1. ... 2. 1. 1.]]

# %%
ave_inflammation = np.mean (data, axis=0)
ave_plot = plt.plot(ave_inflammation)
plt.xlabel ('time(days)')
plt.ylabel ('mean inflammation score')
plt.title ('patient data')
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
max_plot = plt.plot(np.max(data, axis=0))
plt.show()

# %%
min_plot = plt.plot(np.min(data, axis=0))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
fig = plt.figure(figsize=(3.0,10.0))

fig.suptitle('Panel', va='bottom', fontsize=16)

sbplot1 = fig.add_subplot(3, 1, 1)
sbplot2 = fig.add_subplot(3, 1, 2)
sbplot3 = fig.add_subplot(3, 1, 3)

sbplot1.set_ylabel('average')
sbplot1.plot(np.mean(data, axis=0), '--')

sbplot2.set_xlabel('time (days)')
sbplot2.set_ylabel ('max')
sbplot2.plot(np.max(data, axis=0), '-o')

sbplot3.set_ylabel ('min')
sbplot3.plot(np.min(data, axis=0),'--*')

fig.tight_layout()
plt.show()

# %%
ave_inflammation = np.std (data, axis=0)
ave_plot = plt.plot(ave_inflammation)
plt.xlabel ('time(days)')
plt.ylabel ('standard deviation of inflammation score')
plt.title ('patient data')
plt.show()

# %%
#Part 2 of Week 5 HW
#A for loop goes through a set of variables and repeatedly inputs them into the command/code until the last variable is reached, in which it terminates the command/code

for i in range (1, 4):
    print (i)
# Out:
# 1
# 2
# 3

# %%
word = 'oxygen'
for char in word:
 print(char)

#The body of the loop is executed 6 times
# Out:
# o
# x
# y
# g
# e
# n

# %%
x = 4
for i in range(6):
    print (x)
    x = x * 4
# Out:
# 4
# 16
# 64
# 256
# 1024
# 4096

# %%
string = 'Ucla'
reverse_string = ''
for i in string:
    reverse_string = i + reverse_string
print (reverse_string)
# Out:
# alcU

# %%
x = 5
coefs = [2, 4, 3]
y = coefs[0] * x**0 + coefs[1] * x**1 + coefs[2] * x**2
print(y)

y = 9
for idx, coef in enumerate(coefs):
    y = y + coef * x**idx
print (y)
# Out:
# 97
# 106
